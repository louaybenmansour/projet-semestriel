# %% [markdown]
# # 01 - EDA & préparation des données (CRISP-DM)
#
# Ce notebook exécute le pipeline complet (nettoyage, EDA, ingénierie, matrice `X`/`y`, sélection de variables). Les figures sont enregistrées dans `outputs/`.

# %%
from pathlib import Path
import sys

# Racine du projet (contient le dossier src/)
ROOT = Path.cwd().resolve()
if not (ROOT / "src" / "config.py").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.pipeline import run_full_pipeline

run_full_pipeline()
# Out:
# ...
# CRISP-DM: Data Preparation & EDA pipeline
# ...
# Data file: C:\Users\Asus\Desktop\ps2final\data\student_performance_factors.csv
# generate_figures=True
# Note: dropping 7 precomputed/extra column(s) from file to rebuild targets and engineered features consistently: ['Risk', 'Digital_Resources_Score', 'Academic_Stress', 'Low_Attendance', 'Study_Sleep_Ratio', 'Parental_Involvement_Score']...
#
# ...
# 1. DATA CLEANING
# ...
# Shape before cleaning: (6607, 20)
#
# Missing values per column (top):
# Series([], dtype: int64)
#
# Duplicate rows removed: 0
#
# Invalid Exam_Score rows dropped (if any): 0
#
# IQR-based outlier counts (for documentation; not auto-removed):
#   Hours_Studied: 43
#   Attendance: 0
#   Sleep_Hours: 0
#   Previous_Scores: 0
#   Tutoring_Sessions: 430
#   Physical_Activity: 0
#
# Saved: C:\Users\Asus\Desktop\ps2final\outputs\01_boxplots_numeric_outliers.png
#
# Shape after cleaning: (6607, 20)
#
# Key insights:
# ...
